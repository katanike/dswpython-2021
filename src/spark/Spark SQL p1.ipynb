# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-0HM28J7:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.sparkContext
# Out:
# <SparkContext master=local[*] appName=pyspark-shell>

# %%
df = spark.read.parquet('c:/opt/spark-3.1.1-bin-hadoop2.7/examples/src/main/resources/users.parquet')

# %%
df
# Out:
# DataFrame[name: string, favorite_color: string, favorite_numbers: array<int>]

# %%
spark.read

# %%
df.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- favorite_color: string (nullable = true)
#  |-- favorite_numbers: array (nullable = true)
#  |    |-- element: integer (containsNull = true)

# %%
df.show()
# Out:
# +------+--------------+----------------+
# |  name|favorite_color|favorite_numbers|
# +------+--------------+----------------+
# |Alyssa|          null|  [3, 9, 15, 20]|
# |   Ben|           red|              []|
# +------+--------------+----------------+

# %%
df.write.partitionBy("favorite_color").parquet('c:/opt/spark-3.1.1-bin-hadoop2.7/examples/src/main/resources/users_by_color.parquet')

# %%
df.select("name").show()
# Out:
# +------+
# |  name|
# +------+
# |Alyssa|
# |   Ben|
# +------+

# %%
categories = spark.read.parquet("d:/uwm/categories")

# %%
categories
# Out:
# DataFrame[category_id: int, category_department_id: int, category_name: string]

# %%
categories = spark.read.jdbc("d:/uwm/categories")
departments = spark.read.parquet("d:/uwm/departments")
order_items = spark.read.parquet("d:/uwm/order_items")
orders = spark.read.parquet("d:/uwm/orders")
products = spark.read.parquet("d:/uwm/products")

# %%
categories.printSchema()
# Out:
# root
#  |-- category_id: integer (nullable = true)
#  |-- category_department_id: integer (nullable = true)
#  |-- category_name: string (nullable = true)

# %%
departments.printSchema()
# Out:
# root
#  |-- department_id: integer (nullable = true)
#  |-- department_name: string (nullable = true)

# %%
orders.printSchema()
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- order_date: long (nullable = true)
#  |-- order_customer_id: integer (nullable = true)
#  |-- order_status: string (nullable = true)

# %%
orders.schema
# Out:
# StructType(List(StructField(order_id,IntegerType,true),StructField(order_date,LongType,true),StructField(order_customer_id,IntegerType,true),StructField(order_status,StringType,true)))

# %%
categories.show()
# Out:
# +-----------+----------------------+-------------------+
# |category_id|category_department_id|      category_name|
# +-----------+----------------------+-------------------+
# |          1|                     2|           Football|
# |          2|                     2|             Soccer|
# |          3|                     2|Baseball & Softball|
# |          4|                     2|         Basketball|
# |          5|                     2|           Lacrosse|
# |          6|                     2|   Tennis & Racquet|
# |          7|                     2|             Hockey|
# |          8|                     2|        More Sports|
# |          9|                     3|   Cardio Equipment|
# |         10|                     3|  Strength Training|
# |         11|                     3|Fitness Accessories|
# |         12|                     3|       Boxing & MMA|
# |         13|                     3|        Electronics|
# |         14|                     3|     Yoga & Pilates|
# |         15|                     3|  Training by Sport|
# |         16|                     3|    As Seen on  TV!|
# |         17|                     4|             Cleats|
# |         18|                     4|     Men's Footwear|
# |         19|                     4|   Women's Footwear|
# |         20|                     4|     Kids' Footwear|
# +-----------+----------------------+-------------------+
# only showing top 20 rows

# %%
categories.toPandas()
# Out:
#      category_id  category_department_id         category_name
# 0              1                       2              Football
# 1              2                       2                Soccer
# 2              3                       2   Baseball & Softball
# 3              4                       2            Basketball
# 4              5                       2              Lacrosse
# ..           ...                     ...                   ...
# 111           54                       8                   MLS
# 112           55                       8  International Soccer
# 113           56                       8        World Cup Shop
# 114           57                       8           MLB Players
# 115           58                       8           NFL Players
#
# [116 rows x 3 columns]

# %%
categories.count()
# Out:
# 116

# %%
categories.select("category_name").distinct().count()
# Out:
# 55

# %%
order_items.printSchema()
# Out:
# root
#  |-- order_item_id: integer (nullable = true)
#  |-- order_item_order_id: integer (nullable = true)
#  |-- order_item_product_id: integer (nullable = true)
#  |-- order_item_quantity: integer (nullable = true)
#  |-- order_item_subtotal: float (nullable = true)
#  |-- order_item_product_price: float (nullable = true)

# %%
order_items.toPandas()
# Out:
#         order_item_id  order_item_order_id  order_item_product_id  \
# 0                   1                    1                    957
# 1                   2                    2                   1073
# 2                   3                    2                    502
# 3                   4                    2                    403
# 4                   5                    4                    897
# ...               ...                  ...                    ...
# 344391         172194                68881                    403
# 344392         172195                68882                    365
# 344393         172196                68882                    502
# 344394         172197                68883                    208
# 344395         172198                68883                    502
#
#         order_item_quantity  order_item_subtotal  order_item_product_price
# 0                         1           299.980011                299.980011
# 1                         1           199.990005                199.990005
# 2                         5           250.000000                 50.000000
# 3                         1           129.990005                129.990005
# 4                         2            49.980000                 24.990000
# ...                     ...                  ...                       ...
# 344391                    1           129.990005                129.990005
# 344392                    1            59.990002                 59.990002
# 344393                    1            50.000000                 50.000000
# 344394                    1          1999.989990               1999.989990
# 344395                    3           150.000000                 50.000000
#
# [344396 rows x 6 columns]

# %%
orders.printSchema()
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- order_date: long (nullable = true)
#  |-- order_customer_id: integer (nullable = true)
#  |-- order_status: string (nullable = true)

# %%
orders.printSchema()
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- order_date: long (nullable = true)
#  |-- order_customer_id: integer (nullable = true)
#  |-- order_status: string (nullable = true)

# %%
orders.toPandas()
# Out:
#         order_id     order_date  order_customer_id     order_status
# 0              1  1374735600000              11599           CLOSED
# 1              2  1374735600000                256  PENDING_PAYMENT
# 2              3  1374735600000              12111         COMPLETE
# 3              4  1374735600000               8827           CLOSED
# 4              5  1374735600000              11318         COMPLETE
# ...          ...            ...                ...              ...
# 137761     68879  1404889200000                778         COMPLETE
# 137762     68880  1405234800000               1117         COMPLETE
# 137763     68881  1405753200000               2518  PENDING_PAYMENT
# 137764     68882  1406012400000              10000          ON_HOLD
# 137765     68883  1406098800000               5533         COMPLETE
#
# [137766 rows x 4 columns]

# %%
orders.select("order_status").distinct().toPandas()
# Out:
#       order_status
# 0  PENDING_PAYMENT
# 1         COMPLETE
# 2          ON_HOLD
# 3   PAYMENT_REVIEW
# 4       PROCESSING
# 5           CLOSED
# 6  SUSPECTED_FRAUD
# 7          PENDING
# 8         CANCELED

# %%
orders.select("order_status").distinct().collect()
# Out:
# [Row(order_status='PENDING_PAYMENT'),
#  Row(order_status='COMPLETE'),
#  Row(order_status='ON_HOLD'),
#  Row(order_status='PAYMENT_REVIEW'),
#  Row(order_status='PROCESSING'),
#  Row(order_status='CLOSED'),
#  Row(order_status='SUSPECTED_FRAUD'),
#  Row(order_status='PENDING'),
#  Row(order_status='CANCELED')]

# %%
rows = orders.select("order_status").distinct().collect()

# %%
for row in rows:
    print(row)
# Out:
# Row(order_status='PENDING_PAYMENT')
# Row(order_status='COMPLETE')
# Row(order_status='ON_HOLD')
# Row(order_status='PAYMENT_REVIEW')
# Row(order_status='PROCESSING')
# Row(order_status='CLOSED')
# Row(order_status='SUSPECTED_FRAUD')
# Row(order_status='PENDING')
# Row(order_status='CANCELED')

# %%
for row in rows:
    print(row["order_status"])
# Out:
# PENDING_PAYMENT
# COMPLETE
# ON_HOLD
# PAYMENT_REVIEW
# PROCESSING
# CLOSED
# SUSPECTED_FRAUD
# PENDING
# CANCELED

# %%
status_list = sorted([row["order_status"] for row in rows])
status_list
# Out:
# ['CANCELED',
#  'CLOSED',
#  'COMPLETE',
#  'ON_HOLD',
#  'PAYMENT_REVIEW',
#  'PENDING',
#  'PENDING_PAYMENT',
#  'PROCESSING',
#  'SUSPECTED_FRAUD']

# %%
products.printSchema()
# Out:
# root
#  |-- product_id: integer (nullable = true)
#  |-- product_category_id: integer (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- product_description: string (nullable = true)
#  |-- product_price: float (nullable = true)
#  |-- product_image: string (nullable = true)

# %%
products.toPandas()
# Out:
#       product_id  product_category_id  \
# 0              1                    2
# 1              2                    2
# 2              3                    2
# 3              4                    2
# 4              5                    2
# ...          ...                  ...
# 2685        1341                   59
# 2686        1342                   59
# 2687        1343                   59
# 2688        1344                   59
# 2689        1345                   59
#
#                                        product_name product_description  \
# 0     Quest Q64 10 FT. x 10 FT. Slant Leg Instant U
# 1     Under Armour Men's Highlight MC Football Clea
# 2     Under Armour Men's Renegade D Mid Football Cl
# 3     Under Armour Men's Renegade D Mid Football Cl
# 4     Riddell Youth Revolution Speed Custom Footbal
# ...                                             ...                 ...
# 2685  Nike Women's Cleveland Browns Johnny Football
# 2686  Nike Men's St. Louis Rams Michael Sam #96 Nam
# 2687  Nike Men's Home Game Jersey St. Louis Rams Mi
# 2688  Nike Men's Home Game Jersey St. Louis Rams Aa
# 2689  Nike Men's Home Game Jersey St. Louis Rams Gr
#
#       product_price                                      product_image
# 0         59.980000  http://images.acmesports.sports/Quest+Q64+10+F...
# 1        129.990005  http://images.acmesports.sports/Under+Armour+M...
# 2         89.989998  http://images.acmesports.sports/Under+Armour+M...
# 3         89.989998  http://images.acmesports.sports/Under+Armour+M...
# 4        199.990005  http://images.acmesports.sports/Riddell+Youth+...
# ...             ...                                                ...
# 2685      34.000000  http://images.acmesports.sports/Nike+Women%27s...
# 2686      32.000000  http://images.acmesports.sports/Nike+Men%27s+S...
# 2687     100.000000  http://images.acmesports.sports/Nike+Men%27s+H...
# 2688     100.000000  http://images.acmesports.sports/Nike+Men%27s+H...
# 2689     100.000000  http://images.acmesports.sports/Nike+Men%27s+H...
#
# [2690 rows x 6 columns]

# %%
categories.cache()
departments.cache()
order_items.cache()
orders.cache()
products.cache()
# Out:
# DataFrame[product_id: int, product_category_id: int, product_name: string, product_description: string, product_price: float, product_image: string]

# %%
categories.show()
# Out:
# +-----------+----------------------+-------------------+
# |category_id|category_department_id|      category_name|
# +-----------+----------------------+-------------------+
# |          1|                     2|           Football|
# |          2|                     2|             Soccer|
# |          3|                     2|Baseball & Softball|
# |          4|                     2|         Basketball|
# |          5|                     2|           Lacrosse|
# |          6|                     2|   Tennis & Racquet|
# |          7|                     2|             Hockey|
# |          8|                     2|        More Sports|
# |          9|                     3|   Cardio Equipment|
# |         10|                     3|  Strength Training|
# |         11|                     3|Fitness Accessories|
# |         12|                     3|       Boxing & MMA|
# |         13|                     3|        Electronics|
# |         14|                     3|     Yoga & Pilates|
# |         15|                     3|  Training by Sport|
# |         16|                     3|    As Seen on  TV!|
# |         17|                     4|             Cleats|
# |         18|                     4|     Men's Footwear|
# |         19|                     4|   Women's Footwear|
# |         20|                     4|     Kids' Footwear|
# +-----------+----------------------+-------------------+
# only showing top 20 rows

# %%
categories.select("category_name").distinct().count()
# Out:
# 55

# %%
categories.unpersist()
# Out:
# DataFrame[category_id: int, category_department_id: int, category_name: string]

# %%
categories.select(categories.category_name).distinct().count()
# Out:
# 55

# %%
categories.category_name
# Out:
# Column<'category_name'>

# %%
cats_with_dep_name = categories.join(departments)
cats_with_dep_name
# Out:
# DataFrame[category_id: int, category_department_id: int, category_name: string, department_id: int, department_name: string]

# %%
categories.count()
# Out:
# 116

# %%
departments.count()
# Out:
# 12

# %%
cats_with_dep_name.count()
# Out:
# 1392

# %%
116*12
# Out:
# 1392

# %%
cats_with_dep_name.toPandas()
# Out:
#       category_id  category_department_id category_name  department_id  \
# 0               1                       2      Football              2
# 1               1                       2      Football              3
# 2               1                       2      Football              4
# 3               1                       2      Football              5
# 4               1                       2      Football              6
# ...           ...                     ...           ...            ...
# 1387           58                       8   NFL Players              3
# 1388           58                       8   NFL Players              4
# 1389           58                       8   NFL Players              5
# 1390           58                       8   NFL Players              6
# 1391           58                       8   NFL Players              7
#
#      department_name
# 0            Fitness
# 1           Footwear
# 2            Apparel
# 3               Golf
# 4           Outdoors
# ...              ...
# 1387        Footwear
# 1388         Apparel
# 1389            Golf
# 1390        Outdoors
# 1391        Fan Shop
#
# [1392 rows x 5 columns]

# %%
cats = categories.join(departments, categories.category_department_id == departments.department_id)
cats
# Out:
# DataFrame[category_id: int, category_department_id: int, category_name: string, department_id: int, department_name: string]

# %%
cats.toPandas()
# Out:
#      category_id  category_department_id         category_name  department_id  \
# 0              1                       2              Football              2
# 1              1                       2              Football              2
# 2              2                       2                Soccer              2
# 3              2                       2                Soccer              2
# 4              3                       2   Baseball & Softball              2
# ..           ...                     ...                   ...            ...
# 187           46                       7  Indoor/Outdoor Games              7
# 188           47                       7               Boating              7
# 189           47                       7               Boating              7
# 190           48                       7          Water Sports              7
# 191           48                       7          Water Sports              7
#
#     department_name
# 0           Fitness
# 1           Fitness
# 2           Fitness
# 3           Fitness
# 4           Fitness
# ..              ...
# 187        Fan Shop
# 188        Fan Shop
# 189        Fan Shop
# 190        Fan Shop
# 191        Fan Shop
#
# [192 rows x 5 columns]

# %%
cats.columns
# Out:
# ['category_id',
#  'category_department_id',
#  'category_name',
#  'department_id',
#  'department_name']

# %%
cols = ['category_id',
 'category_name',
 'department_id',
 'department_name']

# %%
cats.select(cols).toPandas()
# Out:
#      category_id         category_name  department_id department_name
# 0              1              Football              2         Fitness
# 1              1              Football              2         Fitness
# 2              2                Soccer              2         Fitness
# 3              2                Soccer              2         Fitness
# 4              3   Baseball & Softball              2         Fitness
# ..           ...                   ...            ...             ...
# 187           46  Indoor/Outdoor Games              7        Fan Shop
# 188           47               Boating              7        Fan Shop
# 189           47               Boating              7        Fan Shop
# 190           48          Water Sports              7        Fan Shop
# 191           48          Water Sports              7        Fan Shop
#
# [192 rows x 4 columns]

# %%
cats.printSchema()
# Out:
# root
#  |-- category_id: integer (nullable = true)
#  |-- category_department_id: integer (nullable = true)
#  |-- category_name: string (nullable = true)
#  |-- department_id: integer (nullable = true)
#  |-- department_name: string (nullable = true)

# %%
cats.drop("category_department_id")
# Out:
# DataFrame[category_id: int, category_name: string, department_id: int, department_name: string]

# %%
cats.take(5)
# Out:
# [Row(category_id=1, category_department_id=2, category_name='Football', department_id=2, department_name='Fitness'),
#  Row(category_id=1, category_department_id=2, category_name='Football', department_id=2, department_name='Fitness'),
#  Row(category_id=2, category_department_id=2, category_name='Soccer', department_id=2, department_name='Fitness'),
#  Row(category_id=2, category_department_id=2, category_name='Soccer', department_id=2, department_name='Fitness'),
#  Row(category_id=3, category_department_id=2, category_name='Baseball & Softball', department_id=2, department_name='Fitness')]

# %%
join_types = ["inner", "cross", "outer", "full", "left_outer", "right_outer"]

# %%
for join_type in join_types:
    cats_on_deps = categories.join(departments, categories.category_department_id == departments.department_id, how=join_type)
    count= cats_on_deps.count()
    print(join_type, ": ", count)
# Out:
# inner :  192
# cross :  192
# outer :  212
# full :  212
# left_outer :  212
# right_outer :  192

# %%
categories.sort(categories.category_name).toPandas()
# Out:
#      category_id  category_department_id       category_name
# 0             22                       4         Accessories
# 1             27                       5         Accessories
# 2             40                       6         Accessories
# 3             22                       4         Accessories
# 4             27                       5         Accessories
# ..           ...                     ...                 ...
# 111           31                       6  Women's Golf Clubs
# 112           56                       8      World Cup Shop
# 113           56                       8      World Cup Shop
# 114           14                       3      Yoga & Pilates
# 115           14                       3      Yoga & Pilates
#
# [116 rows x 3 columns]

# %%
import pyspark.sql.functions as F

# %%
categories.sort(F.desc(categories.category_name)).toPandas()
# Out:
#      category_id  category_department_id       category_name
# 0             14                       3      Yoga & Pilates
# 1             14                       3      Yoga & Pilates
# 2             56                       8      World Cup Shop
# 3             56                       8      World Cup Shop
# 4             31                       6  Women's Golf Clubs
# ..           ...                     ...                 ...
# 111           27                       5         Accessories
# 112           40                       6         Accessories
# 113           22                       4         Accessories
# 114           27                       5         Accessories
# 115           40                       6         Accessories
#
# [116 rows x 3 columns]

# %% [markdown]
# ## najbardziej popularne kategorie produktów
#
# ```
# select c.category_name, count(order_item_quantity) as count
# from order_items oi
# inner join products p on oi.order_item_product_id = p.product_id
# inner join categories c on c.category_id = p.product_category_id
# group by c.category_name
# order by count desc
# limit 10;
# ```

# %%
join1 = order_items.join(products, order_items.order_item_product_id == products.product_id)

# %%
join1
# Out:
# DataFrame[order_item_id: int, order_item_order_id: int, order_item_product_id: int, order_item_quantity: int, order_item_subtotal: float, order_item_product_price: float, product_id: int, product_category_id: int, product_name: string, product_description: string, product_price: float, product_image: string]

# %%
join1.printSchema()
# Out:
# root
#  |-- order_item_id: integer (nullable = true)
#  |-- order_item_order_id: integer (nullable = true)
#  |-- order_item_product_id: integer (nullable = true)
#  |-- order_item_quantity: integer (nullable = true)
#  |-- order_item_subtotal: float (nullable = true)
#  |-- order_item_product_price: float (nullable = true)
#  |-- product_id: integer (nullable = true)
#  |-- product_category_id: integer (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- product_description: string (nullable = true)
#  |-- product_price: float (nullable = true)
#  |-- product_image: string (nullable = true)

# %%
join2 = join1.join(categories, categories.category_id == join1.product_category_id)
join2.printSchema()
# Out:
# root
#  |-- order_item_id: integer (nullable = true)
#  |-- order_item_order_id: integer (nullable = true)
#  |-- order_item_product_id: integer (nullable = true)
#  |-- order_item_quantity: integer (nullable = true)
#  |-- order_item_subtotal: float (nullable = true)
#  |-- order_item_product_price: float (nullable = true)
#  |-- product_id: integer (nullable = true)
#  |-- product_category_id: integer (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- product_description: string (nullable = true)
#  |-- product_price: float (nullable = true)
#  |-- product_image: string (nullable = true)
#  |-- category_id: integer (nullable = true)
#  |-- category_department_id: integer (nullable = true)
#  |-- category_name: string (nullable = true)

# %%
join2.toPandas()
# Out:
#          order_item_id  order_item_order_id  order_item_product_id  \
# 0                    1                    1                    957
# 1                    1                    1                    957
# 2                    1                    1                    957
# 3                    1                    1                    957
# 4                    2                    2                   1073
# ...                ...                  ...                    ...
# 1377579         172197                68883                    208
# 1377580         172198                68883                    502
# 1377581         172198                68883                    502
# 1377582         172198                68883                    502
# 1377583         172198                68883                    502
#
#          order_item_quantity  order_item_subtotal  order_item_product_price  \
# 0                          1           299.980011                299.980011
# 1                          1           299.980011                299.980011
# 2                          1           299.980011                299.980011
# 3                          1           299.980011                299.980011
# 4                          1           199.990005                199.990005
# ...                      ...                  ...                       ...
# 1377579                    1          1999.989990               1999.989990
# 1377580                    3           150.000000                 50.000000
# 1377581                    3           150.000000                 50.000000
# 1377582                    3           150.000000                 50.000000
# 1377583                    3           150.000000                 50.000000
#
#          product_id  product_category_id  \
# 0               957                   43
# 1               957                   43
# 2               957                   43
# 3               957                   43
# 4              1073                   48
# ...             ...                  ...
# 1377579         208                   10
# 1377580         502                   24
# 1377581         502                   24
# 1377582         502                   24
# 1377583         502                   24
#
#                                           product_name product_description  \
# 0        Diamondback Women's Serene Classic Comfort Bi
# 1        Diamondback Women's Serene Classic Comfort Bi
# 2        Diamondback Women's Serene Classic Comfort Bi
# 3        Diamondback Women's Serene Classic Comfort Bi
# 4                          Pelican Sunstream 100 Kayak
# ...                                                ...                 ...
# 1377579                            SOLE E35 Elliptical
# 1377580           Nike Men's Dri-FIT Victory Golf Polo
# 1377581           Nike Men's Dri-FIT Victory Golf Polo
# 1377582           Nike Men's Dri-FIT Victory Golf Polo
# 1377583           Nike Men's Dri-FIT Victory Golf Polo
#
#          product_price                                      product_image  \
# 0           299.980011  http://images.acmesports.sports/Diamondback+Wo...
# 1           299.980011  http://images.acmesports.sports/Diamondback+Wo...
# 2           299.980011  http://images.acmesports.sports/Diamondback+Wo...
# 3           299.980011  http://images.acmesports.sports/Diamondback+Wo...
# 4           199.990005  http://images.acmesports.sports/Pelican+Sunstr...
# ...                ...                                                ...
# 1377579    1999.989990  http://images.acmesports.sports/SOLE+E35+Ellip...
# 1377580      50.000000  http://images.acmesports.sports/Nike+Men%27s+D...
# 1377581      50.000000  http://images.acmesports.sports/Nike+Men%27s+D...
# 1377582      50.000000  http://images.acmesports.sports/Nike+Men%27s+D...
# 1377583      50.000000  http://images.acmesports.sports/Nike+Men%27s+D...
#
#          category_id  category_department_id      category_name
# 0                 43                       7   Camping & Hiking
# 1                 43                       7   Camping & Hiking
# 2                 43                       7   Camping & Hiking
# 3                 43                       7   Camping & Hiking
# 4                 48                       7       Water Sports
# ...              ...                     ...                ...
# 1377579           10                       3  Strength Training
# 1377580           24                       5    Women's Apparel
# 1377581           24                       5    Women's Apparel
# 1377582           24                       5    Women's Apparel
# 1377583           24                       5    Women's Apparel
#
# [1377584 rows x 15 columns]

# %%
category_count = join2.groupBy(join2.category_name).count()
category_count
# Out:
# DataFrame[category_name: string, count: bigint]

# %%
category_count.toPandas()
# Out:
#            category_name   count
# 0       Men's Golf Clubs    2264
# 1       Camping & Hiking  109832
# 2    Fitness Accessories    2472
# 3             Golf Shoes    4192
# 4             Basketball     536
# 5         Men's Footwear  177968
# 6            Electronics   25248
# 7        Women's Apparel  168280
# 8         Girls' Apparel    9608
# 9      Golf Bags & Carts     488
# 10       As Seen on  TV!     544
# 11          Boxing & MMA    3384
# 12   Baseball & Softball    5056
# 13    Hunting & Shooting    3520
# 14          Golf Apparel    3528
# 15              Trade-In    7792
# 16    Women's Golf Clubs    1448
# 17         Shop By Sport   87872
# 18               Fishing  138600
# 19          Water Sports  124320
# 20           Accessories   14240
# 21           Golf Gloves    8560
# 22                Cleats  196408
# 23     Strength Training     888
# 24                Soccer    1104
# 25            Golf Balls   11800
# 26      Kids' Golf Clubs    3072
# 27                Hockey    4912
# 28              Lacrosse    2744
# 29      Cardio Equipment   99896
# 30      Tennis & Racquet    2624
# 31  Indoor/Outdoor Games  154384

# %%
category_count.describe().toPandas()
# Out:
#   summary       category_name               count
# 0   count                  32                  32
# 1    mean                None             43049.5
# 2  stddev                None  64476.933808070644
# 3     min         Accessories                 488
# 4     max  Women's Golf Clubs              196408

# %%
category_count.sort(F.desc("count")).toPandas()
# Out:
#            category_name   count
# 0                 Cleats  196408
# 1         Men's Footwear  177968
# 2        Women's Apparel  168280
# 3   Indoor/Outdoor Games  154384
# 4                Fishing  138600
# 5           Water Sports  124320
# 6       Camping & Hiking  109832
# 7       Cardio Equipment   99896
# 8          Shop By Sport   87872
# 9            Electronics   25248
# 10           Accessories   14240
# 11            Golf Balls   11800
# 12        Girls' Apparel    9608
# 13           Golf Gloves    8560
# 14              Trade-In    7792
# 15   Baseball & Softball    5056
# 16                Hockey    4912
# 17            Golf Shoes    4192
# 18          Golf Apparel    3528
# 19    Hunting & Shooting    3520
# 20          Boxing & MMA    3384
# 21      Kids' Golf Clubs    3072
# 22              Lacrosse    2744
# 23      Tennis & Racquet    2624
# 24   Fitness Accessories    2472
# 25      Men's Golf Clubs    2264
# 26    Women's Golf Clubs    1448
# 27                Soccer    1104
# 28     Strength Training     888
# 29       As Seen on  TV!     544
# 30            Basketball     536
# 31     Golf Bags & Carts     488

# %%
categories = spark.read.parquet("d:/uwm/categories")
departments = spark.read.parquet("d:/uwm/departments")
order_items = spark.read.parquet("d:/uwm/order_items")
orders = spark.read.parquet("d:/uwm/orders")
products = spark.read.parquet("d:/uwm/products")

categories.cache()
departments.cache()
order_items.cache()
orders.cache()
products.cache()
# Out:
# DataFrame[product_id: int, product_category_id: int, product_name: string, product_description: string, product_price: float, product_image: string]

# %%
join2 = order_items \
    .join(products, order_items.order_item_product_id == products.product_id) \
    .join(categories, categories.category_id == products.product_category_id)

category_count = join2.groupBy(join2.category_name).count().sort(F.desc("count"))

# %%
category_count.toPandas()
# Out:
#            category_name   count
# 0                 Cleats  196408
# 1         Men's Footwear  177968
# 2        Women's Apparel  168280
# 3   Indoor/Outdoor Games  154384
# 4                Fishing  138600
# 5           Water Sports  124320
# 6       Camping & Hiking  109832
# 7       Cardio Equipment   99896
# 8          Shop By Sport   87872
# 9            Electronics   25248
# 10           Accessories   14240
# 11            Golf Balls   11800
# 12        Girls' Apparel    9608
# 13           Golf Gloves    8560
# 14              Trade-In    7792
# 15   Baseball & Softball    5056
# 16                Hockey    4912
# 17            Golf Shoes    4192
# 18          Golf Apparel    3528
# 19    Hunting & Shooting    3520
# 20          Boxing & MMA    3384
# 21      Kids' Golf Clubs    3072
# 22              Lacrosse    2744
# 23      Tennis & Racquet    2624
# 24   Fitness Accessories    2472
# 25      Men's Golf Clubs    2264
# 26    Women's Golf Clubs    1448
# 27                Soccer    1104
# 28     Strength Training     888
# 29       As Seen on  TV!     544
# 30            Basketball     536
# 31     Golf Bags & Carts     488

# %%
category_count = order_items \
    .join(products, order_items.order_item_product_id == products.product_id) \
    .join(categories, categories.category_id == products.product_category_id) \
    .groupBy(categories.category_name).count().sort(F.desc("count"))

# %%
category_count.toPandas()
# Out:
#            category_name   count
# 0                 Cleats  196408
# 1         Men's Footwear  177968
# 2        Women's Apparel  168280
# 3   Indoor/Outdoor Games  154384
# 4                Fishing  138600
# 5           Water Sports  124320
# 6       Camping & Hiking  109832
# 7       Cardio Equipment   99896
# 8          Shop By Sport   87872
# 9            Electronics   25248
# 10           Accessories   14240
# 11            Golf Balls   11800
# 12        Girls' Apparel    9608
# 13           Golf Gloves    8560
# 14              Trade-In    7792
# 15   Baseball & Softball    5056
# 16                Hockey    4912
# 17            Golf Shoes    4192
# 18          Golf Apparel    3528
# 19    Hunting & Shooting    3520
# 20          Boxing & MMA    3384
# 21      Kids' Golf Clubs    3072
# 22              Lacrosse    2744
# 23      Tennis & Racquet    2624
# 24   Fitness Accessories    2472
# 25      Men's Golf Clubs    2264
# 26    Women's Golf Clubs    1448
# 27                Soccer    1104
# 28     Strength Training     888
# 29       As Seen on  TV!     544
# 30            Basketball     536
# 31     Golf Bags & Carts     488

# %%
categories.createOrReplaceTempView("categories")
departments.createOrReplaceTempView("departments")
order_items.createOrReplaceTempView("order_items")
products.createOrReplaceTempView("products")

# %%
wynik = spark.sql("""

select c.category_name, count(order_item_quantity) as count
from order_items oi
inner join products p on oi.order_item_product_id = p.product_id
inner join categories c on c.category_id = p.product_category_id
group by c.category_name
order by count desc

""")

# %%
wynik
# Out:
# DataFrame[category_name: string, count: bigint]

# %%
wynik.toPandas()
# Out:
#            category_name   count
# 0                 Cleats  196408
# 1         Men's Footwear  177968
# 2        Women's Apparel  168280
# 3   Indoor/Outdoor Games  154384
# 4                Fishing  138600
# 5           Water Sports  124320
# 6       Camping & Hiking  109832
# 7       Cardio Equipment   99896
# 8          Shop By Sport   87872
# 9            Electronics   25248
# 10           Accessories   14240
# 11            Golf Balls   11800
# 12        Girls' Apparel    9608
# 13           Golf Gloves    8560
# 14              Trade-In    7792
# 15   Baseball & Softball    5056
# 16                Hockey    4912
# 17            Golf Shoes    4192
# 18          Golf Apparel    3528
# 19    Hunting & Shooting    3520
# 20          Boxing & MMA    3384
# 21      Kids' Golf Clubs    3072
# 22              Lacrosse    2744
# 23      Tennis & Racquet    2624
# 24   Fitness Accessories    2472
# 25      Men's Golf Clubs    2264
# 26    Women's Golf Clubs    1448
# 27                Soccer    1104
# 28     Strength Training     888
# 29       As Seen on  TV!     544
# 30            Basketball     536
# 31     Golf Bags & Carts     488
